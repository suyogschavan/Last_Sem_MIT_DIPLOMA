# %% [markdown]
# Process EEG Data with Plotly in Python/v3

# %%
import mne
import pathlib
import matplotlib

# %%
matplotlib.use('Qt5Agg')

import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\Users\SUYOG_~1\AppData\Local\Temp/ipykernel_3392/2683575761.py in <module>
# ----> 1 matplotlib.use('Qt5Agg')
#       2
#       3 import numpy as np
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\__init__.py in use(backend, force)
#    1142                 # user does not have the libraries to support their
#    1143                 # chosen backend installed.
# -> 1144                 plt.switch_backend(name)
#    1145             except ImportError:
#    1146                 if force:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in switch_backend(newbackend)
#     265     backend_name = cbook._backend_module_name(newbackend)
#     266
# --> 267     class backend_mod(matplotlib.backend_bases._Backend):
#     268         locals().update(vars(importlib.import_module(backend_name)))
#     269
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in backend_mod()
#     266
#     267     class backend_mod(matplotlib.backend_bases._Backend):
# --> 268         locals().update(vars(importlib.import_module(backend_name)))
#     269
#     270     required_framework = _get_required_interactive_framework(backend_mod)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_qt5agg.py in <module>
#       3 """
#       4
# ----> 5 from .backend_qtagg import (
#       6     _BackendQTAgg, FigureCanvasQTAgg, FigureManagerQT, NavigationToolbar2QT,
#       7     backend_version,  FigureCanvasAgg,  FigureCanvasQT
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_qtagg.py in <module>
#       7 from matplotlib.transforms import Bbox
#       8
# ----> 9 from .qt_compat import QT_API, _enum, _setDevicePixelRatio
#      10 from .. import cbook
#      11 from .backend_agg import FigureCanvasAgg
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\qt_compat.py in <module>
#     126         break
#     127     else:
# --> 128         raise ImportError("Failed to import any qt binding")
#     129 else:  # We should not get there.
#     130     raise AssertionError(f"Unexpected QT_API: {QT_API}")
#
# ImportError: Failed to import any qt binding

# %%
mne.set_log_level('WARNING')
sample_data_dir = mne.datasets.sample.data_path()
sample_data_dir = pathlib.Path(sample_data_dir)
sample_data_dir
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\SUYOG_~1\AppData\Local\Temp/ipykernel_3392/4069787844.py in <module>
#       1 mne.set_log_level('WARNING')
# ----> 2 sample_data_dir = mne.datasets.sample.data_path()
#       3 sample_data_dir = pathlib.Path(sample_data_dir)
#       4 sample_data_dir
#
# <decorator-gen-535> in data_path(path, force_update, update_path, download, verbose)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\datasets\sample\sample.py in data_path(path, force_update, update_path, download, verbose)
#      22               verbose=None):  # noqa: D103
#      23
# ---> 24     return _download_mne_dataset(
#      25         name='sample', processor='untar', path=path,
#      26         force_update=force_update, update_path=update_path,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\datasets\utils.py in _download_mne_dataset(name, processor, path, force_update, update_path, download, accept)
#     186             dataset_params.append(this_dataset)
#     187
# --> 188     return fetch_dataset(dataset_params=dataset_params, processor=processor_,
#     189                          path=path, force_update=force_update,
#     190                          update_path=update_path, download=download,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\datasets\_fetch.py in fetch_dataset(dataset_params, processor, path, force_update, update_path, download, check_version, return_version, accept, auth, token)
#     250         # fetch and unpack the data
#     251         archive_name = dataset_params[idx]["archive_name"]
# --> 252         fetcher.fetch(
#     253             fname=archive_name, downloader=downloader, processor=processor
#     254         )
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pooch\core.py in fetch(self, fname, processor, downloader)
#     537                 downloader = choose_downloader(url)
#     538
# --> 539             stream_download(
#     540                 url,
#     541                 full_path,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pooch\core.py in stream_download(url, fname, known_hash, downloader, pooch, retry_if_failed)
#     722             # hash before overwriting the original.
#     723             with temporary_file(path=str(fname.parent)) as tmp:
# --> 724                 downloader(url, tmp, pooch)
#     725                 hash_matches(tmp, known_hash, strict=True, source=str(fname.name))
#     726                 shutil.move(tmp, str(fname))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pooch\downloaders.py in __call__(self, url, output_file, pooch)
#     202                 progress = self.progressbar
#     203                 progress.total = total
# --> 204             for chunk in content:
#     205                 if chunk:
#     206                     output_file.write(chunk)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py in generate()
#     756             if hasattr(self.raw, 'stream'):
#     757                 try:
# --> 758                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     759                         yield chunk
#     760                 except ProtocolError as e:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     574         else:
#     575             while not is_fp_closed(self._fp):
# --> 576                 data = self.read(amt=amt, decode_content=decode_content)
#     577
#     578                 if data:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in read(self, amt)
#     456             # Amount is given, implement using readinto
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#     460         else:
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in readinto(self, b)
#     500         # connection, and the user is reading more bytes than will be provided
#     501         # (for example, reading in 1k chunks)
# --> 502         n = self.fp.readinto(b)
#     503         if not n and b:
#     504             # Ideally, we would raise IncompleteRead if the content-length
#
# ~\AppData\Local\Programs\Python\Python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\AppData\Local\Programs\Python\Python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\AppData\Local\Programs\Python\Python39\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
raw_path = sample_data_dir / 'MEG' / 'sample' / 'sample_audvis_raw.fif'
raw = mne.io.read_raw_fif(raw_path)
raw
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SUYOG_~1\AppData\Local\Temp/ipykernel_3392/2713732928.py in <module>
# ----> 1 raw_path = sample_data_dir / 'MEG' / 'sample' / 'sample_audvis_raw.fif'
#       2 raw = mne.io.read_raw_fif(raw_path)
#       3 raw
#
# NameError: name 'sample_data_dir' is not defined
